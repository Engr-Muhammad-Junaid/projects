# %% [markdown]
# # dataframe mean data in the form of rows and columns

# %% [markdown]
# # pandas is used to make your data in the form of data frame(rows and columns)

# %%
import pandas as pd

# %%
df=pd.read_csv('F:\jupyter\survey_results_public.csv')

# %%
#by defualt it is takes 20 columns
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df.sort_values(by=['Country', 'ConvertedComp'], ascending=[True, False], inplace=True)
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 62723       63129                     I am a developer by profession      Yes
# 50172       50499  I am not primarily a developer, but I write co...      Yes
# 39018       39258                     I am a developer by profession      Yes
# 58082       58450                     I am a developer by profession      Yes
# 7056         7085                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88873       88062                                                NaN       No
# 88874       88076                                                NaN       No
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
#
# ...

# %%
df[['Country', 'ConvertedComp']].head(50)
# Out:
#            Country  ConvertedComp
# 62723  Afghanistan      1000000.0
# 50172  Afghanistan       153216.0
# 39018  Afghanistan        19152.0
# 58082  Afghanistan        17556.0
# 7056   Afghanistan        14364.0
# 22327  Afghanistan         7980.0
# 48122  Afghanistan         4464.0
# 10697  Afghanistan         3996.0
# 8112   Afghanistan         1596.0
# 29560  Afghanistan         1116.0
# 719    Afghanistan            0.0
# 28470  Afghanistan            0.0
# 6391   Afghanistan            NaN
# 7323   Afghanistan            NaN
# 12253  Afghanistan            NaN
# 26189  Afghanistan            NaN
# 28877  Afghanistan            NaN
# 32971  Afghanistan            NaN
# 37571  Afghanistan            NaN
# 39754  Afghanistan            NaN
# 42832  Afghanistan            NaN
# 44123  Afghanistan            NaN
# 45562  Afghanistan            NaN
# 46807  Afghanistan            NaN
# 49377  Afghanistan            NaN
# 50437  Afghanistan            NaN
# ...

# %%
#if you know that how many columns and rows are there in data set we can use shape attribute
df.shape
# Out:
# (88883, 85)

# %%
df['ConvertedComp'].nlargest(10)
# Out:
# 25833    2000000.0
# 87353    2000000.0
# 21895    2000000.0
# 28080    2000000.0
# 72274    2000000.0
# 77665    2000000.0
# 79701    2000000.0
# 51798    2000000.0
# 75088    2000000.0
# 32056    2000000.0
# Name: ConvertedComp, dtype: float64

# %%
#there is another method called info which gives the detail of data set according to rows and column
#it's shown the data type of rows and columns also and the object shown the string here
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 88883 entries, 62723 to 88881
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  object
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
# ...

# %%
df.nsmallest(10, 'ConvertedComp')
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 719           722                     I am a developer by profession       No
# 28470       28638                     I am a developer by profession      Yes
# 13760       13825                     I am a developer by profession      Yes
# 40655       40913                     I am a developer by profession      Yes
# 30447       30630                     I am a developer by profession      Yes
# 68611       69049                     I am a developer by profession       No
# 19235       19340  I am not primarily a developer, but I write co...      Yes
# 16126       16214  I am not primarily a developer, but I write co...      Yes
# 29184       29355                     I am a developer by profession      Yes
# 1678         1685                     I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# ...

# %%
#here we want to see the all columns we change the setting in jupyter
pd.set_option('display.max_columns',85)
#we can also do same for rows

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 62723       63129                     I am a developer by profession      Yes
# 50172       50499  I am not primarily a developer, but I write co...      Yes
# 39018       39258                     I am a developer by profession      Yes
# 58082       58450                     I am a developer by profession      Yes
# 7056         7085                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88873       88062                                                NaN       No
# 88874       88076                                                NaN       No
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
#
# ...

# %%
#now we will take the schema file which to know what the column do(what is the meaning of each column)
schema_df=pd.read_csv('F:\jupyter\data\survey_results_schema.csv',index_col='Column')
#here we make the column is a index

# %%
#in above we have seen the columns name but we don't know about the colunms actual meaning so here
#in schema each columns shown the actual meaning like Hobbiyes columns mean(do u have code as a hobby)
schema_df
# Out:
#                                                    QuestionText
# Column
# Respondent    Randomized respondent ID number (not in order ...
# MainBranch    Which of the following options best describes ...
# Hobbyist                                Do you code as a hobby?
# OpenSourcer         How often do you contribute to open source?
# OpenSource    How do you feel about the quality of open sour...
# ...                                                         ...
# Sexuality     Which of the following do you currently identi...
# Ethnicity     Which of the following do you identify as? Ple...
# Dependents    Do you have any dependents (e.g., children, el...
# SurveyLength  How do you feel about the length of the survey...
# SurveyEase    How easy or difficult was this survey to compl...
#
# [85 rows x 1 columns]

# %%
#row index and other is columns
schema_df.loc['Student','QuestionText']
#schema_df.loc['Student']
# Out:
# 'Are you currently enrolled in a formal, degree-granting college or university program?'

# %%
#taking all the rows ther is total 85 rowns in schema
pd.set_option('display.max_rows',85)
schema_df
# Out:
#                                                              QuestionText
# Column
# Respondent              Randomized respondent ID number (not in order ...
# MainBranch              Which of the following options best describes ...
# Hobbyist                                          Do you code as a hobby?
# OpenSourcer                   How often do you contribute to open source?
# OpenSource              How do you feel about the quality of open sour...
# Employment              Which of the following best describes your cur...
# Country                         In which country do you currently reside?
# Student                 Are you currently enrolled in a formal, degree...
# EdLevel                 Which of the following best describes the high...
# UndergradMajor          What was your main or most important field of ...
# EduOther                Which of the following types of non-degree edu...
# OrgSize                 Approximately how many people are employed by ...
# ...

# %%
#taking first rows
schema_df.head(10)
#taking last rows
schema_df.tail()
# Out:
#                                                    QuestionText
# Column
# Sexuality     Which of the following do you currently identi...
# Ethnicity     Which of the following do you identify as? Ple...
# Dependents    Do you have any dependents (e.g., children, el...
# SurveyLength  How do you feel about the length of the survey...
# SurveyEase    How easy or difficult was this survey to compl...

# %%
schema_df.sort_index(ascending=True)
# Out:
#                                                              QuestionText
# Column
# Age                     What is your age (in years)? If you prefer not...
# Age1stCode              At what age did you write your first line of c...
# BetterLife              Do you think people born today will have a bet...
# BlockchainIs            Blockchain / cryptocurrency technology is prim...
# BlockchainOrg           How is your organization thinking about or imp...
# CareerSat               Overall, how satisfied are you with your caree...
# CodeRev                          Do you review code as part of your work?
# CodeRevHrs              On average, how many hours per week do you spe...
# CompFreq                 Is that compensation weekly, monthly, or yearly?
# CompTotal               What is your current total compensation (salar...
# Containers              How do you use containers (Docker, Open Contai...
# ConvertedComp           Salary converted to annual USD salaries using ...
# ...

# %%
df['Dependents'].value_counts()
# Out:
# No     50727
# Yes    32332
# Name: Dependents, dtype: int64

# %%
df.loc[0:2,'Respondent':'Employment']
# Out:
# Empty DataFrame
# Columns: [Respondent, MainBranch, Hobbyist, OpenSourcer, OpenSource, Employment]
# Index: []

# %%
#filtering
filt=(df['ConvertedComp']>70000)

# %%
counteries=['Pakistan','Canada','United kingdom','Japan']
df.loc[filt]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 62723       63129                     I am a developer by profession      Yes
# 50172       50499  I am not primarily a developer, but I write co...      Yes
# 38075       38308                     I am a developer by profession      Yes
# 3771         3787                     I am a developer by profession      Yes
# 9230         9270                     I am a developer by profession       No
# ...           ...                                                ...      ...
# 54820       55168                     I am a developer by profession      Yes
# 5329         5352  I am not primarily a developer, but I write co...      Yes
# 29072       29241                     I am a developer by profession       No
# 33542       33751                     I am a developer by profession       No
# 55057       55405                     I am a developer by profession      Yes
#
# ...

# %%
df[df['Country'].isin(counteries)]
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 25833       25983          I am a developer by profession      Yes
# 30487       30670          I am a developer by profession      Yes
# 272           274          I am a developer by profession       No
# 14910       14985          I am a developer by profession       No
# 271           273          I am a developer by profession      Yes
# ...           ...                                     ...      ...
# 88310       88862  I am a student who is learning to code      Yes
# 88353        5439                                     NaN      Yes
# 88567       39117                                     NaN      Yes
# 88710       60066                                     NaN      Yes
# 88875       88182                                     NaN      Yes
#
#                                              OpenSourcer  \
# 25833                            Less than once per year
# ...

# %%
df['ConvertedComp'].head(15)
# Out:
# 62723    1000000.0
# 50172     153216.0
# 39018      19152.0
# 58082      17556.0
# 7056       14364.0
# 22327       7980.0
# 48122       4464.0
# 10697       3996.0
# 8112        1596.0
# 29560       1116.0
# 719            0.0
# 28470          0.0
# 6391           NaN
# 7323           NaN
# 12253          NaN
# Name: ConvertedComp, dtype: float64

# %%
#median is best as compare to mean b/s the outliear effect the mean as much as compare to median
df['ConvertedComp'].median()
# Out:
# 57287.0

# %%
df.median()
# Out:
# Respondent       44442.0
# CompTotal        62000.0
# ConvertedComp    57287.0
# WorkWeekHrs         40.0
# CodeRevHrs           4.0
# Age                 29.0
# dtype: float64

# %%
#apply on whole data frame instead on single columns
df.describe()
# Out:
#          Respondent     CompTotal  ConvertedComp   WorkWeekHrs    CodeRevHrs  \
# count  88883.000000  5.594500e+04   5.582300e+04  64503.000000  49790.000000
# mean   44442.000000  5.519014e+11   1.271107e+05     42.127197      5.084308
# std    25658.456325  7.331926e+13   2.841523e+05     37.287610      5.513931
# min        1.000000  0.000000e+00   0.000000e+00      1.000000      0.000000
# 25%    22221.500000  2.000000e+04   2.577750e+04     40.000000      2.000000
# 50%    44442.000000  6.200000e+04   5.728700e+04     40.000000      4.000000
# 75%    66662.500000  1.200000e+05   1.000000e+05     44.750000      6.000000
# max    88883.000000  1.000000e+16   2.000000e+06   4850.000000     99.000000
#
#                 Age
# count  79210.000000
# mean      30.336699
# std        9.178390
# min        1.000000
# 25%       24.000000
# 50%       29.000000
# 75%       35.000000
# max       99.000000

# %%
# it count the all values in each columns
#If we want to count all the values with respect to row then we have to pass axis=1 or ‘columns’.
df['ConvertedComp'].count()
# Out:
# 55823

# %%
df['Hobbyist']
# Out:
# 62723    Yes
# 50172    Yes
# 39018    Yes
# 58082    Yes
# 7056     Yes
#         ...
# 88873     No
# 88874     No
# 88879     No
# 88880     No
# 88881     No
# Name: Hobbyist, Length: 88883, dtype: object

# %%
#how many there is yes and No:(Value Counts are limited only for a single 
#column or series and it's sole purpose is to return the series of frequencies of values)

df['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df['SocialMedia']
# Out:
# 62723    I don't use social media
# 50172                    WhatsApp
# 39018                    Facebook
# 58082                    Facebook
# 7056                    Instagram
#                    ...
# 88873                         NaN
# 88874                         NaN
# 88879                         NaN
# 88880                         NaN
# 88881                         NaN
# Name: SocialMedia, Length: 88883, dtype: object

# %%
schema_df.loc['SocialMedia']
# Out:
# QuestionText    What social media site do you use the most?
# Name: SocialMedia, dtype: object

# %%
df['SocialMedia'].value_counts()
# Out:
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: SocialMedia, dtype: int64

# %%
#normalize use to percentage the values
df['SocialMedia'].value_counts(normalize=True)
# Out:
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: SocialMedia, dtype: float64

# %%
#here we make the group on basis of country
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('India')
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 21895       22013                     I am a developer by profession      Yes
# 28080       28243                     I am a developer by profession      Yes
# 72274       72732  I am not primarily a developer, but I write co...       No
# 16703       16793                     I am a developer by profession      Yes
# 52225       52561                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88808       77339                                                NaN      Yes
# 88825       79795                                                NaN      Yes
# 88852       83862                                                NaN      Yes
# 88853       84299                                                NaN      Yes
# 88864       86012                                                NaN      Yes
#
# ...
