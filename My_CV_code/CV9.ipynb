# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
#cv2 read your image as oppoiste order BGR

# %%
pic1=cv2.imread('C://Users//Muhammad junaid//Downloads//dog_backpack.jpg')
pic1=cv2.cvtColor(pic1,cv2.COLOR_BGR2RGB)
pic2=cv2.imread('C://Users//Muhammad junaid//Downloads//watermark_no_copy.png')
pic2=cv2.cvtColor(pic2,cv2.COLOR_BGR2RGB)
plt.imshow(pic2)

# %%
pic2.shape
# Out:
# (1280, 1277, 3)

# %%
#here we are going to resizing the these images so we can show you can directly paste images on top of eachother and blended them together.
#lets do blending images of the same size
pic1=cv2.resize(pic1,(1200,1200))
pic2=cv2.resize(pic2,(1200,1200))

# %%
plt.imshow(pic1)
plt.imshow(pic2)

# %%
blended=cv2.addWeighted(pic1,0.5,pic2,0.7,0)
plt.imshow(blended)
#don't copy have white background that's why it shown the some white color on top of the dogs_pack background

# %%
blended=cv2.addWeighted(pic1,0.8,pic2,0.1,0)
plt.imshow(blended)

# %%
#overlay the image of the different sizes with blended
img1=cv2.imread('C://Users//Muhammad junaid//Downloads//dog_backpack.jpg')
img1=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
img2=cv2.imread('C://Users//Muhammad junaid//Downloads//watermark_no_copy.png')
img2=cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)
#numpy consider your x_axis is a column and y_axis of your image is numpy rows

# %%
img1=cv2.resize(img1,(1200,1200))

# %%
img1.shape
# Out:
# (1200, 1200, 3)

# %%
img2=cv2.resize(img2,(600,600))

# %%
larger_img=img1
small_img=img2

# %%
x_offset=0
y_offset=0
x_end=0+img2.shape[1]
y_end=0+img2.shape[0]

# %%
img2.shape[1]
# Out:
# 600

# %%
larger_img[y_offset:y_end,x_offset:x_end]=small_img

# %%
plt.imshow(larger_img)

# %%
larger_img[600:1200,600:1200]=small_img

# %%
plt.imshow(larger_img)
