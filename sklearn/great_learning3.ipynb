# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ipl=pd.read_csv('F:\jupyter\deliveries.csv')
ipl.head(3)
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
ipl[(ipl['batsman']=='DA Warner') & (ipl['ball']==3) & (ipl['match_id']==1) &(ipl['over']==1)]
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# 2            0            0             0             4           0
#
#    total_runs  player_dismissed dismissal_kind fielder
# 2           4               NaN            NaN     NaN
#
# [1 rows x 21 columns]

# %%
match_ist=ipl[(ipl['match_id']==1)]
match_ist
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
store=match_ist[(match_ist['batting_team']=='Sunrisers Hyderabad')]

# %%
store['batsman'].unique()
# Out:
# array(['DA Warner', 'S Dhawan', 'MC Henriques', 'Yuvraj Singh',
#        'DJ Hooda', 'BCJ Cutting'], dtype=object)

# %%
store['dismissal_kind'].value_counts()
# Out:
# caught    3
# bowled    1
# Name: dismissal_kind, dtype: int64

# %%
match_2=ipl[ipl['match_id']==2]
match_2
# Out:
#      match_id  inning            batting_team            bowling_team  over  \
# 248         2       1          Mumbai Indians  Rising Pune Supergiant     1
# 249         2       1          Mumbai Indians  Rising Pune Supergiant     1
# 250         2       1          Mumbai Indians  Rising Pune Supergiant     1
# 251         2       1          Mumbai Indians  Rising Pune Supergiant     1
# 252         2       1          Mumbai Indians  Rising Pune Supergiant     1
# ..        ...     ...                     ...                     ...   ...
# 490         2       2  Rising Pune Supergiant          Mumbai Indians    20
# 491         2       2  Rising Pune Supergiant          Mumbai Indians    20
# 492         2       2  Rising Pune Supergiant          Mumbai Indians    20
# 493         2       2  Rising Pune Supergiant          Mumbai Indians    20
# 494         2       2  Rising Pune Supergiant          Mumbai Indians    20
#
# ...

# %%
match_2[match_2['inning']==1]
p=match_2[(match_2['batting_team']=='Mumbai Indians')]
p['total_runs'].value_counts()
# Out:
# 1    55
# 0    41
# 4    12
# 6    11
# 2     5
# 5     1
# Name: total_runs, dtype: int64
