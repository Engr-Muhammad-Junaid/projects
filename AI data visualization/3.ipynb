# %%
import pandas as np
import numpy as np
import seaborn as sns

# %%
data=sns.load_dataset('titanic')

# %%
#creating the boxplot or box and whisker plot it's used for quartile information
sns.boxplot(x='fare',data=data)
# Out:
# <AxesSubplot:xlabel='fare'>

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#it's give the overall dist for numeric columns like normal dist 
#the color shown the 50th percentile the obove one is 75th and other below is 25th percentile
sns.violinplot(x='alone',y='age',data=data)
# Out:
# NumExpr defaulting to 4 threads.
# <AxesSubplot:xlabel='alone', ylabel='age'>

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']=[7,6]
plt.style.use('fivethirtyeight')
plt.grid('darkgrid')
data['age'].hist(edgecolor='black',bins=[10,20,30,40,50,60,70,80,90])
# Out:
# <AxesSubplot:>

# %%
flight=sns.load_dataset('flights')
flight.plot.line(x='year',y='passengers')
# Out:
# <AxesSubplot:xlabel='year'>

# %%
flight.plot.scatter(x='year',y='passengers')
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
#barplot 
mean_age=data.groupby('sex')['age'].mean()
mean_age
# Out:
# sex
# female    27.915709
# male      30.726645
# Name: age, dtype: float64

# %%
df=pd.DataFrame({'sex':['male','female'],'age':mean_age.tolist()})
df.plot.bar(x='sex',y='age')
# Out:
# <AxesSubplot:xlabel='sex'>

# %%
sns.boxplot(x=data['age'])
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# <AxesSubplot:>

# %%
data.plot.box()
# Out:
# <AxesSubplot:>

# %%
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-c0c655d1c164> in <module>
# ----> 1 plt.barh(x='sex',y='age',width=0.7,data=data)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in barh(y, width, height, left, align, **kwargs)
#    2500 @_copy_docstring_and_deprecators(Axes.barh)
#    2501 def barh(y, width, height=0.8, left=None, *, align='center', **kwargs):
# -> 2502     return gca().barh(
#    2503         y, width, height=height, left=left, align=align, **kwargs)
#    2504
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in barh(self, y, width, height, left, align, **kwargs)
#    2628         """
#    2629         kwargs.setdefault('orientation', 'horizontal')
# -> 2630         patches = self.bar(x=left, height=height, width=width, bottom=y,
#    2631                            align=align, **kwargs)
#    2632         return patches
#
# ...
