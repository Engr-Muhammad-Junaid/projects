# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=sns.load_dataset('tips')

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#sns.distplot(data['total_bill'],bins=5)

# %%
from scipy.stats import norm

# %%
#sns.distplot(data['tip'],fit=norm,kde=True,vertical=True,hist=False)

# %%
#join plot is used to draw the histogram dist for two columns one on the x_axis and other is on
#the y axis and scatter plot is drawn by default
sns.jointplot(x=data['total_bill'],y=data['tip'],kind='reg')
# Out:
# NumExpr defaulting to 4 threads.

# %%
sns.jointplot(x='size',y='total_bill',data=data,kind='reg')

# %%
sns.pairplot(data=data)

# %%
#barplot is used to capture the relationship between categorical and numerical columns
#the categorical is on the x_axis and on the y_axis by default it shown the mean of the each categorie
titanic=sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
plt.rcParams['figure.figsize']=[7,5]
sns.barplot(x=titanic['sex'],y=titanic['age'],data=titanic)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
# Out:
# <BarContainer object of 891 artists>

# %%
d=titanic[(titanic['sex']=='female')]

# %%
d['age'].mean()
# Out:
# 27.915708812260537

# %%
#countplot is use to plot the each count values of the unique categorical values on the y_axis
sns.countplot(x=titanic['sex'],data=titanic)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>
